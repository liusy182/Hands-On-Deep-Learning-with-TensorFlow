# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

pickle_file = './nomnist/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)

image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    print('\ndata.shape:', data.shape)
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    print('\nconv1.shape:', conv.shape)
    hidden = tf.nn.relu(conv + layer1_biases)
    print('\nhidden1.shape:', hidden.shape)
    
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    print('\nconv2.shape:', conv.shape)
    hidden = tf.nn.relu(conv + layer2_biases)
    print('\nhidden2.shape:', hidden.shape)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    print('\nreshape.shape:', reshape.shape)
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))


num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# data.shape: (16, 28, 28, 1)
#
# conv1.shape: (16, 14, 14, 16)
#
# hidden1.shape: (16, 14, 14, 16)
#
# conv2.shape: (16, 7, 7, 16)
#
# hidden2.shape: (16, 7, 7, 16)
#
#  reshape.shape: (16, 784)
#
# data.shape: (10000, 28, 28, 1)
#
# conv1.shape: (10000, 14, 14, 16)
#
# hidden1.shape: (10000, 14, 14, 16)
#
# conv2.shape: (10000, 7, 7, 16)
#
# hidden2.shape: (10000, 7, 7, 16)
#
#  reshape.shape: (10000, 784)
#
# data.shape: (10000, 28, 28, 1)
#
# conv1.shape: (10000, 14, 14, 16)
#
# hidden1.shape: (10000, 14, 14, 16)
#
# conv2.shape: (10000, 7, 7, 16)
#
# hidden2.shape: (10000, 7, 7, 16)
#
#  reshape.shape: (10000, 784)
# WARNING:tensorflow:From /Users/liusi/repo/git/machinelearning/dl-tensorflow/ENV/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.474269
# Minibatch accuracy: 0.0%
# Validation accuracy: 12.7%
# Minibatch loss at step 50: 2.319990
# Minibatch accuracy: 6.2%
# Validation accuracy: 11.7%
# Minibatch loss at step 100: 1.311983
# Minibatch accuracy: 56.2%
# Validation accuracy: 56.1%
# Minibatch loss at step 150: 0.664206
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.9%
# Minibatch loss at step 200: 0.524042
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 250: 0.758592
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.1%
# Minibatch loss at step 300: 0.768288
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 350: 0.676619
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 400: 0.919597
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 450: 0.593341
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 0.324557
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.772327
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.942776
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 650: 0.555399
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 700: 0.644882
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 750: 0.146776
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 800: 0.639049
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 850: 0.660136
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 900: 0.921650
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 950: 0.783179
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000: 0.593011
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Test accuracy: 89.7%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))


num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From /Users/liusi/repo/git/machinelearning/dl-tensorflow/ENV/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 4.009514
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.954634
# Minibatch accuracy: 25.0%
# Validation accuracy: 45.9%
# Minibatch loss at step 100: 1.162248
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.7%
# Minibatch loss at step 150: 0.543329
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.6%
# Minibatch loss at step 200: 0.514259
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 250: 0.768719
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss at step 300: 0.849043
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 350: 0.791201
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 400: 0.873935
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 450: 0.505374
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 500: 0.394480
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 550: 0.530032
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 600: 0.797914
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 650: 0.544378
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 700: 0.651554
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 750: 0.186677
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.683528
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 850: 0.478627
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 900: 0.695381
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 950: 0.732440
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.522995
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Test accuracy: 89.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    conv = tf.nn.dropout(conv, 0.5)
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    conv = tf.nn.dropout(conv, 0.5)
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))


num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From /Users/liusi/repo/git/machinelearning/dl-tensorflow/ENV/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 7.711524
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.156394
# Minibatch accuracy: 12.5%
# Validation accuracy: 33.1%
# Minibatch loss at step 100: 1.190029
# Minibatch accuracy: 81.2%
# Validation accuracy: 50.6%
# Minibatch loss at step 150: 0.818202
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.1%
# Minibatch loss at step 200: 0.671478
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.8%
# Minibatch loss at step 250: 0.965013
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 300: 0.548441
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.3%
# Minibatch loss at step 350: 0.635220
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.9%
# Minibatch loss at step 400: 0.865536
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 450: 0.686601
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 500: 0.506974
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 550: 1.329930
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.5%
# Minibatch loss at step 600: 0.718303
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 650: 0.516350
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 700: 0.654932
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 750: 0.137792
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 800: 0.990854
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 850: 0.591864
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 900: 0.744401
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 950: 0.828064
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 1000: 0.863307
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Test accuracy: 87.8%
