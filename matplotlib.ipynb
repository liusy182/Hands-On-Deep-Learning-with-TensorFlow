# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

data = np.arange(10).astype(np.float32)
data = data / 2
plt.plot(data)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(np.arange(10))

ax2 = fig.add_subplot(2, 2, 4)
ax2.plot(~np.arange(20))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8d9af91999b1> in <module>()
#       1 fig, axes = plt.subplots(1, 1)
# ----> 2 data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
#       3 data.plot.bar(ax=axes[0], color='k', alpha=0.7)
#
# NameError: name 'pd' is not defined
